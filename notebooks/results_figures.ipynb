# %% [markdown]
# # Results figures
#
# Empty placeholder. Populate in Phase 2/3 with plots read from `results/` (latency vs seq_len, roofline, HBM bytes moved) once real benchmark/profile numbers exist.
